# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

#使用chrome的webdriver
browser = webdriver.Chrome()
#開啟網頁
browser.get('http://35.201.209.150:5000/')
#視窗最大化
browser.maximize_window()
#輸入帳號密碼進行登入
element = browser.find_element_by_name ("username").send_keys("tami")
element = browser.find_element_by_name ("pwd").send_keys("tami")
element = browser.find_element_by_css_selector('.btn.btn-primary.hidden-xs.btn-login').click()

#開啟左側特徵管理
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/a').click()
#切換到特徵列表
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/ul/li[1]/a').click()
#按下新增特徵+
time.sleep(3)
element = browser.find_element_by_xpath('//html/body/section/div/section/div/div[1]/div/div[1]/button').click()
#選擇特徵歸群
time.sleep(5)
element = browser.find_element_by_xpath('//*[@id="cate1"]/option[5]').click()
#按下新增條件
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/header/h2/button').click()

time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[1]/div/div/select/option[6]').click()

time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[1]/a').click()

#第一層 選3C
element = browser.find_element_by_xpath('//*[@id="select2-chosen-1"]').click()
element = browser.find_element_by_xpath('//*[@id="product_label1"]/option[2]').click()
time.sleep(3)
#第二層 全選
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[2]/div/div[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[2]/div/div[1]/span/span/span/div/ul/li[2]/a/label').click()
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[2]/div/div[1]/span/span/span/div/button').click()
#第三層 全選
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[3]/div/div[1]/span/span/span/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[3]/div/div[1]/span/span/span/span/span/span/div/ul/li[2]/a/label').click()
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[3]/div/div[1]/span/span/span/span/span/span/div/button').click()
#第四層 全選
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[4]/div/div[1]/span/span/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[4]/div/div[1]/span/span/span/span/span/div/ul/li[2]').click()
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[1]/div[2]/div[4]/div/div[1]/span/span/span/span/span/div/button').click()
#選擇感興趣
element = browser.find_element_by_xpath('//*[@id="modalProductTag"]/section/div/div/div/div[2]/div[1]/div/div[2]/div/div[1]/label').click()
#輸入金額
element = browser.find_element_by_name ("product_lowest_price").send_keys("0")
element = browser.find_element_by_name ("product_highest_price").send_keys("26000")
#按下新增離開新此畫面
element = browser.find_element_by_css_selector('.btn.btn-primary.btn-add-product-tag').click()

#時間及平率設定
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[1]/input[@value="period"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[2]/select/option[2]').click()
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[3]/input[3]').click()
element = browser.find_element_by_name ("times").clear()
element = browser.find_element_by_name ("times").send_keys("1")
#輸入特徵命名
element = browser.find_element_by_name ("feature_name").send_keys("3C達人")
time.sleep(3)
element = browser.find_element_by_name ("feature_description").send_keys("購買3C產品囉~")
time.sleep(30)
element = browser.find_element_by_xpath("/html/body/section/div/section/section/div/div/div[1]/div[5]/div/button[2]").click()
#如果需要執行完自動關閉，就要加上下面這一行
#browser.close()
