# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.ui import Select

#使用chrome的webdriver
browser = webdriver.Chrome()
#開啟網頁
browser.get('http://35.201.209.150:5000/')
#視窗最大化
browser.maximize_window()
#輸入帳號密碼進行登入
element = browser.find_element_by_name ("username").send_keys("itri")
element = browser.find_element_by_name ("pwd").send_keys("itri")
element = browser.find_element_by_css_selector('.btn.btn-primary.hidden-xs.btn-login').click()

#切換到受眾列表
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[1]/ul/li[1]/a').click()
#按下新增受眾+
element = browser.find_element_by_xpath('/html/body/section/div/section/div/div[1]/div/div[1]/button').click()
#選擇受眾歸群
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="cate1"]/option[3]').click()
#受眾命名
element = browser.find_element_by_name ("target_name").send_keys("金融")
element = browser.find_element_by_name ("target_description").send_keys("市場金融人數")
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[1]/div/div/div/div[1]/div/input[1]').click()

#受眾條件1
#包含條件
#基本輪廓設定
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[1]/div/section/header/div[2]/a/i').click()
#性別:男性與女性
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/div/div/div[1]/div[1]/div[2]/input[1]').send_keys(Keys.SPACE)
#年齡:1至100歲
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/div/div/div[1]/div[2]/div[2]/div[1]/div/div/div[1]/select/option[21]').click()
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/div/div/div[1]/div[2]/div[2]/div[1]/div/div/div[3]/select/option[61]').click()
#地址類別 戶籍地址-台中市全區
element = browser.find_element_by_xpath('//input[@value="billing"]').send_keys(Keys.SPACE)
s1 = Select(browser.find_element_by_name("county"))
s1.select_by_visible_text("台北市")
#新增一組基本輪廓設定
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/footer/div/div/button[1]').click()
time.sleep(15)
#特徵條件 交集
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[2]/div/div/div/div[1]/div/input[1]').send_keys(Keys.SPACE)

#位移
browser.execute_script('window.scrollBy(0,300)')

#排除條件
#基本輪廓設定
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[2]/div/section/header/div[2]/a/i').click()
#性別:男性
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/div/div/div[1]/div[1]/div[2]/input[1]').send_keys(Keys.SPACE)
#年齡:1至100歲
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/div/div/div[1]/div[2]/div[2]/div[1]/div/div/div[1]/select/option[56]').click()
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/div/div/div[1]/div[2]/div[2]/div[1]/div/div/div[3]/select/option[61]').click()
#地址類別 帳單地址:台北市 全區
element = browser.find_element_by_xpath('//input[@value="permanent"]').send_keys(Keys.SPACE)
s1 = Select(browser.find_element_by_name("county"))
s1.select_by_visible_text("台中市")
element = browser.find_element_by_xpath('//input[@value="東區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="南區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="西區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="北區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="北屯區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="西屯區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="南屯區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="太平區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="大里區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="霧峰區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="烏日區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="豐原區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="后里區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="石岡區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="東勢區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="和平區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="新社區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="潭子區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="大雅區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="神岡區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="大肚區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="沙鹿區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="龍井區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="梧棲區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="清水區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="大甲區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="外埔區"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('//input[@value="大安區"]').send_keys(Keys.SPACE)
#新增一組基本輪廓設定
element = browser.find_element_by_xpath('//*[@id="modalBasicShape"]/section/footer/div/div/button[1]').click()

#特徵條件 聯集
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[2]/div/div/div/div[1]/div/input[2]').send_keys(Keys.SPACE)
time.sleep(10)
#新增受眾
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/header/div/div[2]/div[2]/button[1]').click()
