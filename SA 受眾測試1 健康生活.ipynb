# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

#使用chrome的webdriver
browser = webdriver.Chrome()
#開啟網頁
browser.get('http://35.201.209.150:5000/')
#視窗最大化
browser.maximize_window()
#輸入帳號密碼進行登入
element = browser.find_element_by_name ("username").send_keys("tami")
element = browser.find_element_by_name ("pwd").send_keys("tami")
element = browser.find_element_by_css_selector('.btn.btn-primary.hidden-xs.btn-login').click()

#開啟左側受眾管理
#time.sleep(3)
###element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[5]/a').click()
#切換到受眾列表
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[5]/ul/li[1]/a').click()
#按下新增受眾+
element = browser.find_element_by_xpath('/html/body/section/div/section/div/div[1]/div/div[1]/button').click()
#選擇受眾歸群
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="cate1"]/option[3]').click()
#受眾命名
element = browser.find_element_by_name ("target_name").send_keys("健康生活")
element = browser.find_element_by_name ("target_description").send_keys("包含慈善、吃、與金融")
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[1]/div/div/div/div[1]/div/input[2]').click()

#受眾條件1
#包含條件
#基本輪廓設定
###element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[1]/div/section/header/div[2]/a/i').click()
#特徵條件 聯集
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[1]/div/div/div/div[1]/div/input[2]').click()
#顯示特徵條件
###element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[1]/a').click()
time.sleep(1)
#打開關注事項
element = browser.find_element_by_xpath('//*[@id="j1_1"]/i').click()
time.sleep(1)
#加入 做慈善是好事
element = browser.find_element_by_xpath('//*[@id="j1_4"]/a/div/div[2]').click()
time.sleep(10)
#打開基本輪廓
element = browser.find_element_by_xpath('//*[@id="j1_6"]/i').click()
time.sleep(1)
element = browser.find_element_by_xpath('//*[@id="j1_7"]/a/div/div[2]').click()
time.sleep(65)
#加入 北美洲與金融
element = browser.find_element_by_xpath('//*[@id="j1_2"]/a/div/div[2]').click()
time.sleep(70)

#排除條件
#基本輪廓設定
###element = browser.find_element_by_xpath('').click()
#特徵條件 聯集
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/div[1]/div[1]/div/div/div[2]/section[2]/div/div/div/div[1]/div/input[2]').send_keys(Keys.SPACE)
time.sleep(75)
#加入 電信公司
element = browser.find_element_by_xpath('//*[@id="j1_14"]/i').click()
element = browser.find_element_by_xpath('//*[@id="j1_15_anchor"]/div/div[1]').click()
time.sleep(70)
#加入 亞洲土豪
element = browser.find_element_by_xpath('//*[@id="j1_11"]/i').click()
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="j1_13_anchor"]/div/div[1]').click()
time.sleep(100)
#新增受眾
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div[2]/header/div/div[2]/div[2]/button[1]').click()
#while not link:
#    try:
#        link = driver.find_element_by_xpath(linkAddress)
#    except NoSuchElementException:
#        time.sleep(2)
