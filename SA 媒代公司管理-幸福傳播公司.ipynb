# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time

#使用chrome的webdriver
browser = webdriver.Chrome()
#開啟網頁
browser.get('http://35.201.209.150:5000/')
#視窗最大化
#browser.maximize_window()
#輸入帳號密碼進行登入
element = browser.find_element_by_name ("username").send_keys("tami")
element = browser.find_element_by_name ("pwd").send_keys("tami")
element = browser.find_element_by_css_selector('.btn.btn-primary.hidden-xs.btn-login').click()

#開啟左側媒代公司管理
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[1]/a').click()
#切換到媒代公司列表
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[1]/ul/li[1]/a').click()
#建立媒代公司
element = browser.find_element_by_xpath('/html/body/section/div/section/div/div/div[1]/button').click()

#公司資訊
#媒代公司名稱-幸福傳播公司
element = browser.find_element_by_name ("agency_name").send_keys("幸福傳播公司")
#統一編號-75986336
element = browser.find_element_by_name ("gui_nb").send_keys("75986336")
#公司地址-基隆市仁愛區光大路455號
element = browser.find_element_by_name ("address").send_keys("基隆市仁愛區光大路455號")
#主要聯絡人-楊香錦
element = browser.find_element_by_name ("contact").send_keys("楊香錦")
#聯絡人電話-0988655888
element = browser.find_element_by_name ("contact_phone").send_keys("0988655888")
#財務聯絡人-歐陽哲宇
element = browser.find_element_by_name ("finance_contact").send_keys("歐陽哲宇")
#財務聯絡人電話-0913555999
element = browser.find_element_by_name ("finance_contact_phone").send_keys("0913555999")

#方案管理
#廣告主數量-2
element = browser.find_element_by_name ("advertiser_nb").send_keys("2")
#Agency Admin 數量-2
element = browser.find_element_by_name ("aa_nb").send_keys("2")
#Agency User 數量-4
element = browser.find_element_by_name ("au_nb").send_keys("4")

#媒代公司有效期限-2019/11/03~2020/07/31
element = browser.find_element_by_name ("contract_start_dt").send_keys("2019/11/03")
element = browser.find_element_by_name ("contract_end_dt").send_keys("2020/07/31")

#下一步
element = browser.find_element_by_xpath('/html/body/section/div/section/div/div/div/section/div[2]/ul/li[3]/a').click()

#基本資料
#帳號-sia@tami.com.tw
element = browser.find_element_by_name ("username").send_keys("sia@tami.com.tw")
#姓名-楊香錦
element = browser.find_element_by_name ("name").send_keys("楊香錦")
#電話-0988655888
element = browser.find_element_by_name ("phone").send_keys("0988655888")
#優先權-2
element = browser.find_element_by_name ("priority").clear()
element = browser.find_element_by_name ("priority").send_keys("2")

#勾選"基本輪廓、愛吃又愛動、洲與洲之間"
#勾選"基本輪廓、愛心富豪、金融"
