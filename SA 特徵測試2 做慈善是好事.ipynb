# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time

#使用chrome的webdriver
browser = webdriver.Chrome()
#開啟網頁
browser.get('http://35.201.209.150:5000/')
#視窗最大化
#browser.maximize_window()
#輸入帳號密碼進行登入
element = browser.find_element_by_name ("username").send_keys("tami")
element = browser.find_element_by_name ("pwd").send_keys("tami")
element = browser.find_element_by_css_selector('.btn.btn-primary.hidden-xs.btn-login').click()

#開啟左側特徵管理
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/a').click()
#切換到特徵列表
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/ul/li[1]/a').click()
#按下新增特徵+
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/div/div[1]/div[1]/button').click()
#選擇特徵歸群 1基本輪廓 2關注事項 
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="cate1"]/option[2]').click()
#按下新增條件
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/header/h2/button').click()
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[1]/div/div/select/option[3]').click()
time.sleep(3)
#資料來源 Call Tree
#對應下層 call_label1
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[1]/a').click()

#第一層 非營利組織
s1 = Select(browser.find_element_by_id('call_label1'))
s1.select_by_visible_text("非營利組織")
#element = browser.find_element_by_xpath('//*[@id="select2-chosen-1"]').click()
#element = browser.find_element_by_xpath('//*[@id="select2-results-1"]/li[35]').click()
#第二層 基金會、捐款
time.sleep(1)
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/ul/li[5]').click()
time.sleep(1)
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/ul/li[6]').click()
time.sleep(1)
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
#簡訊類別-全選
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/span/div/ul/li[2]').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/span/div/button').click()
#標籤屬性-商品品牌
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/span/div/ul/li[5]').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/span/div/button').click()
#品牌標籤-品牌名稱
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[2]/div/div/div[3]/span/span/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//input[@value="104夢想搖籃"]').click()
element = browser.find_element_by_xpath('//input[@value="「張老師」基金會"]').click()
element = browser.find_element_by_xpath('//input[@value="一粒麥子基金會"]').click()
element = browser.find_element_by_xpath('//input[@value="七星生態保育基金會"]').click()
element = browser.find_element_by_xpath('//input[@value="三洋維士比基金會"]').click()
element = browser.find_element_by_xpath('//input[@value="中信慈善基金會"]').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[2]/div/div/div[3]/span/span/span/span/span/div/button').click()
#新增
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/footer/div/div/button[1]').click()


#按下新增條件
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[1]/a').click()


#輸入特徵命名
element = browser.find_element_by_name ("feature_name").send_keys("做慈善是好事")
time.sleep(2)
element = browser.find_element_by_name ("feature_description").send_keys("可能吧，如果捐對的話")
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/div[3]/div[2]/label[2]/input').send_keys(Keys.SPACE)
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/div[5]/div/button[2]').click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-10-50af0bdf2c1d> in <module>
#      73 #按下新增條件
#      74 time.sleep(3)
# ---> 75 element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[1]/a').click()
#      76
#      77
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
# ...
