# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time

#使用chrome的webdriver
browser = webdriver.Chrome()
#開啟網頁
browser.get('http://35.201.209.150:5000/')
#視窗最大化
browser.maximize_window()
#輸入帳號密碼進行登入
element = browser.find_element_by_name ("username").send_keys("tami")
element = browser.find_element_by_name ("pwd").send_keys("tami")
element = browser.find_element_by_css_selector('.btn.btn-primary.hidden-xs.btn-login').click()

#開啟左側特徵管理
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/a').click()
#切換到特徵列表
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/ul/li[1]/a').click()
#按下新增特徵+
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/div/div[1]/div[1]/button').click()
#選擇特徵歸群
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="cate1"]/option[3]').click()
#按下新增條件
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/header/h2/button').click()
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[1]/div/div/select/option[2]').click()
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[1]/a').click()

#第一層 食物與餐飲
s1 = Select(browser.find_element_by_id('behavior_label1'))
s1.select_by_visible_text("食物與餐飲")
#element = browser.find_element_by_xpath('//*[@id="select2-chosen-1"]').click()
#element = browser.find_element_by_xpath('//*[@id="select2-results-1"]/li[35]').click()
time.sleep(3)
#第二層 全選
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//input[@value="multiselect-all"]').click()
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
#關聯性強度-強
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/ul/li[6]').click()
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/button').click()
#標籤屬性-商品品牌、平台
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/ul/li[5]').click()
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/ul/li[6]').click()
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/button').click()
#新增
element = browser.find_element_by_xpath('//*[@id="modalBehaviorTag"]/section/footer/div/div/button[1]').click()
time.sleep(5)
#時間及平率設定 最近期間1年
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[1]/input[@value="period"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[2]/select/option[2]').click()
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[3]/input[3]').click()
element = browser.find_element_by_name ("times").clear()
element = browser.find_element_by_name ("times").send_keys("2")

#新增排除條件
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[2]/header/h2/button').click()
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[2]/div/div/div/section/div/div[1]/div/div/select/option[4]').click()
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[2]/div/div/div/section/div/div[2]/div[1]/a').click()
time.sleep(7)
#第一層標籤 運動與健身
s1 = Select(browser.find_element_by_id('cdr_label1'))
s1.select_by_visible_text("運動與健身")
#第二層標籤
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//input[@value="multiselect-all"]').click()
time.sleep(2)
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
#電話區域 全選
time.sleep(2)
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div').click()
#選北北基、南投、台中、台南
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/ul/li[6]').click()
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/ul/li[7]').click()
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/ul/li[8]').click()
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/ul/li[9]').click()
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div').click()
#發/受話-全選
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div').click()
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/ul/li[2]').click()
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div').click()
#新增
element = browser.find_element_by_xpath('//*[@id="modalCDRTag"]/section/footer/div/div/button[1]').click()

#時間及平率設定 最近期間1天
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[2]/div/div/div/section/div/div[2]/div[2]/div[3]/div[1]/input[@value="period"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[2]/div/div/div/section/div/div[2]/div[2]/div[3]/div[2]/select').click()
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[2]/div/div/div/section/div/div[2]/div[2]/div[3]/div[2]/select/option[2]').click()
#輸入特徵命名
element = browser.find_element_by_name ("feature_name").send_keys("又吃又愛動")
time.sleep(3)
element = browser.find_element_by_name ("feature_description").send_keys("裡面包含食物餐飲但排除運動健身")
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/div[3]/div[2]/label[2]/input').send_keys(Keys.SPACE)
time.sleep(5)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/div[5]/div/button[2]').click()
#如果需要執行完自動關閉，就要加上下面這一行
#browser.close()
