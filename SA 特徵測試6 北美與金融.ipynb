# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time

#使用chrome的webdriver
browser = webdriver.Chrome()
#開啟網頁
browser.get('http://35.201.209.150:5000/')
#視窗最大化
browser.maximize_window()
#輸入帳號密碼進行登入
element = browser.find_element_by_name ("username").send_keys("tami")
element = browser.find_element_by_name ("pwd").send_keys("tami")
element = browser.find_element_by_css_selector('.btn.btn-primary.hidden-xs.btn-login').click()

#開啟左側特徵管理
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/a').click()
#切換到特徵列表
time.sleep(3)
element = browser.find_element_by_xpath('//*[@id="menu"]/ul/li[4]/ul/li[1]/a').click()
#按下新增特徵+
time.sleep(3)
element = browser.find_element_by_xpath('//html/body/section/div/section/div/div[1]/div/div[1]/button').click()
#選擇特徵歸群 2關注事項 
time.sleep(5)
element = browser.find_element_by_xpath('//*[@id="cate1"]/option[2]').click()
#按下新增條件 
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/header/h2/button').click()
time.sleep(3)
#資料來源 Call Tree
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[1]/div/div/select/option[3]').click()
time.sleep(3)
#對應下層 call_label1                     
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[1]/a').click()

#第一層 銀行與金融
s1 = Select(browser.find_element_by_id('call_label1'))
s1.select_by_visible_text("銀行與金融")
time.sleep(1)
#第二層 全選                             
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//input[@value="multiselect-all"]').click()
time.sleep(1)
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
#簡訊類別-全選
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/ul/li[2]').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[1]/span/span/span/div/button').click()
#標籤屬性-全選                            
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/ul/li[2]/a/label').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[1]/div[3]/div[3]/div/div/span[2]/span/span/span/div/button').click()
#品牌名稱-全選                            
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[2]/div/div/div[3]/span/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[2]/div/div/div[3]/span/span/span/span/div/ul/li[2]/a/label').click()
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/div/div/div/div[2]/div/div/div[3]/span/span/span/span/div/button').click()

#新增 
time.sleep(2)
element = browser.find_element_by_xpath('//*[@id="modalCallTreeTag"]/section/footer/div/div/button[1]').click()

#時間及平率設定 最近期間1年總次數1次        
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[1]/input[@value="period"]').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[2]/select/option[2]').click()
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div/section/div/div[2]/div[2]/div[3]/div[3]/input[3]').click()
element = browser.find_element_by_name ("times").clear()
element = browser.find_element_by_name ("times").send_keys("1")
time.sleep(20)

#按下新增條件
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/header/h2/button').click()
#選擇條件"OR"
time.sleep(3)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div[2]/div/div/label[2]/input').send_keys(Keys.SPACE)
#資料來源 TDR Tree
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div[2]/section/div/div[1]/div/div/select/option[5]').click()
time.sleep(3)
#對應下層 call_label1                     
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div[2]/section/div/div[2]/div[1]/a').click()

#第一層 北美洲
s1 = Select(browser.find_element_by_id('tdr_label1'))
s1.select_by_visible_text("北美洲")
time.sleep(2)
#第二層 全選                             
element = browser.find_element_by_xpath('//*[@id="modalTDRTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
element = browser.find_element_by_xpath('//*[@id="modalTDRTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/ul/li[2]/a/label/input').click()
time.sleep(2)
element = browser.find_element_by_xpath('//*[@id="modalTDRTag"]/section/div/div/div/div[1]/div[3]/div[2]/div/div[1]/span/span/span/div/button').click()
#新增 
time.sleep(2)
element = browser.find_element_by_xpath('//*[@id="modalTDRTag"]/section/footer/div/div/button[1]').click()
#時間及平率設定 指定時間區間:2019/10/01~2019/10/31
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div[2]/section/div/div[2]/div[2]/div[2]/div[1]/input').send_keys(Keys.SPACE)
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div[2]/section/div/div[2]/div[2]/div[2]/div[2]/div/input[1]').send_keys("2019/10/01")
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/section[1]/div/div/div[2]/section/div/div[2]/div[2]/div[2]/div[2]/div/input[2]').send_keys("2019/10/31")
element = browser.find_element_by_name ("times").clear()
element = browser.find_element_by_name ("times").send_keys("1")


#輸入特徵命名 北美與金融
element = browser.find_element_by_name ("feature_name").send_keys("北美與金融")
time.sleep(3)
#輸入特徵描述 特別關注金融市場
element = browser.find_element_by_name ("feature_description").send_keys("特別關注金融市場")
#權限設定:開放編輯
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/div[3]/div[2]/label[2]/input').send_keys(Keys.SPACE)
time.sleep(10)
#創建此特徵
element = browser.find_element_by_xpath('/html/body/section/div/section/section/div/div/div[1]/div[5]/div/button[2]').click()
